# %%
# %sql
CREATE TABLE IF NOT EXISTS gold_stock_metrics
USING DELTA
LOCATION 's3://stock-market-data-charan/gold';

# %%
# %sql
SELECT * FROM gold_stock_metrics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>symbol</th><th>avg_price</th><th>total_volume</th><th>avg_open_price</th><th>avg_high_price</th><th>avg_low_price</th></tr></thead><tbody><tr><td>AAPL</td><td>282.5368655395508</td><td>2.6210158854E10</td><td>281.29018432617187</td><td>281.5586791992188</td><td>280.99470092773436</td></tr><tr><td>MSFT</td><td>372.1961476135254</td><td>1.8636680646E10</td><td>371.4220864868164</td><td>371.7134982299805</td><td>371.1445999145508</td></tr><tr><td>TSLA</td><td>380.1391879272461</td><td>5.346696496E9</td><td>380.60432006835936</td><td>380.9040051269531</td><td>380.29111114501956</td></tr><tr><td>AMZN</td><td>231.11343757629393</td><td>2.485963733E10</td><td>229.53871673583984</td><td>229.71591033935547</td><td>229.34411224365235</td></tr><tr><td>GOOGL</td><td>339.3488589477539</td><td>1.1478257441E10</td><td>341.359508972168</td><td>341.59909973144534</td><td>341.0679397583008</td></tr></tbody></table></div>
