# %%
# %sql
CREATE TABLE IF NOT EXISTS bronze_stock
USING DELTA
LOCATION 's3://stock-market-data-charan/bronze';

# %%
# %sql
SELECT * FROM bronze_stock;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
